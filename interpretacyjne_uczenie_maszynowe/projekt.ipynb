# %% [markdown]
# Pozyskać dane na temat wyników wyborów w USA w 2016. [Zbiór ZIP](Datasets/trump.zip) [Z podziałem na zmienne](trump.csv)

# %% [markdown]
# [link do materiałów](https://www.dropbox.com/scl/fo/282y4hxzvp5a4e9y3eetx/h?rlkey=x7wihyz0rxhcr2191qiihhrbx&dl=0)

# %%
import pandas as pd
dane = pd.read_csv("Datasets/trump.csv")
dane.head()
# Out:
#     GISJOIN  county_code  FIPS       YEAR    STATE  STATEA          COUNTY  \
# 0  G0100010         1001  1001  2012-2016  Alabama       1  Autauga County
# 1  G0100030         1003  1003  2012-2016  Alabama       1  Baldwin County
# 2  G0100050         1005  1005  2012-2016  Alabama       1  Barbour County
# 3  G0100070         1007  1007  2012-2016  Alabama       1     Bibb County
# 4  G0100090         1009  1009  2012-2016  Alabama       1   Blount County
#
#    COUNTYA                     NAME  RUCC_2013  ...  transp_public  \
# 0        1  Autauga County, Alabama        2.0  ...       0.000782
# 1        3  Baldwin County, Alabama        3.0  ...       0.002143
# 2        5  Barbour County, Alabama        6.0  ...       0.003871
# 3        7     Bibb County, Alabama        1.0  ...       0.004831
# 4        9   Blount County, Alabama        1.0  ...       0.001733
#
#    pov_under_1  insured_under65  house_vacant  housevalue_median  POP16dens  \
# ...

# %% [markdown]
# Dane zawierają następujące kolumny:

# %%
dane.columns
# Out:
# Index(['GISJOIN', 'county_code', 'FIPS', 'YEAR', 'STATE', 'STATEA', 'COUNTY',
#        'COUNTYA', 'NAME', 'RUCC_2013', 'election_votes_dem',
#        'election_votes_gop', 'election_total_votes', 'election_per_dem',
#        'election_per_gop', 'race_white', 'race_black', 'race_hispanic',
#        'sex_female', 'age_0_17', 'age_over65', 'ind_divorce',
#        'marriage_never_married', 'lang_second_eng', 'empl_civilian_unemployed',
#        'ind_agriculture', 'income_median', 'public_asist', 'gini_index',
#        'transp_car', 'transp_public', 'pov_under_1', 'insured_under65',
#        'house_vacant', 'housevalue_median', 'POP16dens', 'MEDIAN_INCOME08_16',
#        'POP08_16', 'edu_high', 'housevalue_IQR'],
#       dtype='object')

# %% [markdown]
# Co oznaczają poszczególne zmienne:
#
# |    zmienna                 | co oznacza                     |
# |----------------------------|--------------------------------|
# | 'race_white'               | White rate                     |
# | 'race_black'               | White rate                     |
# | 'race_hispanic'            | Hispanic rate                  |
# | 'sex_female'               | Female rate                    |
# | 'age_0_17'                 | People under 18 rate           |
# | 'age_over65'               | People over 65 rate            |
# | 'ind_divorce'              | Divorce index                  |
# | 'marriage_never_married'   | Singleness rate                |
# | 'lang_second_eng'          | Non-English rate               |
# | 'empl_civilian_unemployed' | Unemployment rate              |
# | 'ind_agriculture'          | Employed in agriculture rate   |
# | 'income_median'            | Median income                  |
# | 'public_asist'             | Public assistance rate         |
# | 'gini_index'               | Gini index                     |
# | 'transp_car'               | Use car frequency              |
# | 'transp_public'            | Use public transport frequency |
# | 'pov_under_1'              | Real poverty index             |
# | 'insured_under65'          | Insurance rate                 |
# | 'house_vacant'             |  Vacant houses rate            |
# | 'housevalue_median'        | Median of house value          |
# | 'POP16dens'                | Poulation density              |
# | 'MEDIAN_INCOME08_16'       | Income change index            |
# | 'POP08_16'                 | Population change index        |
# | 'edu_high'                 | High education rate            |
# | 'housevalue_IQR'           | House value spread             |

# %% [markdown]
# Elementy projektu:
#
# * Wytrenować model na całym zbiorze danych, użyć dowolnego modelu innego niż Random Forest, Extra Trees i XGBoost
# * Wykonać transformację zmiennych do shapely values z użyciem wykonanego modelu
# * Wykonać wykresy całkowitej zależności pomiędzy 6 najważniejszymi zmiennymi a wartościami shapely values. ZINTERPETOWAĆ ROLĘ ZMIENNYCH
# * Wykonać wykresy wodospadowe dla wybranych counties (minimum 6)
#
#   NA OCENĘ BARDZO DOBRĄ:
# * Zidentyfikować dowolną formalną metodą 49 różnych counties po jednym reprezentancie dla każdego stanu.Wykonać dla nich wykresy wodospadowe oraz heatmapę. Dokonać interpretacji różnych czynników wpływających na wynik wyborów we wskazanych counties
