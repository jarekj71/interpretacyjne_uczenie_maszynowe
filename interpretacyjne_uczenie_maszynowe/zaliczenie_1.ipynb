# %% [markdown]
# ## Pcaca zaliczeniowa I

# %%
import pandas as pd

data = pd.read_csv("Datasets/praca_hausing.csv")
data
# Out:
#      pietro  izby  powierzchnia  zadrzewienie   autostrada   przemysł  \
# 0         0     4         65.10         13.44   3153.81100   63.63961
# 1         3     2         32.70         21.56   8452.07227  134.35030
# 2         0     3         40.98          1.20   6571.53900   89.44272
# 3         3     2         49.53          0.48  11763.63574  207.00241
# 4         4     3         81.40         21.72   4384.95500  169.18920
# ..      ...   ...           ...           ...          ...        ...
# 995       1     2         25.10          5.20   4261.23535   95.52486
# 996       1     5        118.70          5.04   6369.22700   60.20797
# 997       0     3         43.70         29.64   4216.83500  261.96380
# 998       3     2         45.70          9.24   4425.45459   61.84658
# 999       2     3         36.50          4.44   5521.06200  240.83190
#
#         centrum     jezioro        lasy     tramwaj     policja      szkola  \
# ...

# %% [markdown]
# Dane zawierają dwie zmienne wyjaśniane:
#
# - binarną *zainter*, która oznacza czy dana nieruchomość cieszy się zainteresowaniem czy nie (cokolwiek to znaczy)
# - numeryczną *cena* (dane mocno nieaktualne). Zmienna ta jest również jedną ze zmiennych wyjaśniających dla zmiennej *zainter*
#
# Zmienne wyjaśniające to informacje na temat odległości budynków od wybranych obiektów przestrzennych
#
# W ramach pracy należy:
#
# - określić zależności liniowe pomiędzy zmiennymi wyjaśnianymi a wyjaśnianymi. Należy pamiętać o transformacjach
# - Czy wszystkie zmienne wyjaśniające powinny być numeryczne?
# - wskazać zmienne o małej przydatności dla modelu liniowego
# - wskazać, które zmienne zachowują się nieliniowo i czy zmiany te są uzasadnione rozkładem tych zmiennych
# - Wskazać jaka część zakresu zmiennych wpływa na zwyżkę ceny (lub zwiększa prawdpodobieństwo zainteresowania) a jaka obniża te cechy.
